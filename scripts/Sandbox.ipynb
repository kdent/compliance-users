# %%
import build_users_data as build
import projects 
import facilities
import users_and_facilities
import users_and_projects

import pandas as pd

# %%
reporting_periods = ['2013-2014', '2015-2017', '2018-2020', '2021']
mrr_data_years = ['2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']

compliance_report_path = '../data/compliance-reports/'
mrr_data_path = '../data/mrr-data/'
issuance_table_path = '../data/'

# %%
mrr_file_year = {
    '2013': '2019',
    '2014': '2019',
    '2015': '2019',
    '2016': '2020',
    '2017': '2020',
    '2018': '2020',
    '2019': '2020',
    '2020': '2021',
    '2021': '2022'
}
reporting_periods = {
    '2013': '2013-2014',
    '2014': '2013-2014',
    '2015': '2015-2017',
    '2016': '2015-2017',
    '2017': '2015-2017',
    '2018': '2018-2020',
    '2019': '2018-2020',
    '2020': '2018-2020',
    '2021': '2021'
}

# %%
project_df = projects.read_project_data(issuance_table_path)

# %%
facility_df = facilities.read_facility_data(mrr_data_path, mrr_data_years)
# Out:
# /srv/conda/envs/notebook/lib/python3.9/site-packages/openpyxl/worksheet/_reader.py:315: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
user_project_df = users_and_projects.read_user_project_data(compliance_report_path, reporting_periods)

# %%
user_facility_df = users_and_facilities.read_user_facility_data(
        compliance_report_path, reporting_periods
    )

# %%
user_facility_df
# Out:
#     user_id                                 user_name facility_id  \
# 0    CA1000                       Oildale Energy, LLC      100891
# 1    CA1001                    The Newark Group, Inc.      104135
# 1    CA1001                    The Newark Group, Inc.      104136
# 2    CA1003  Plumas-Sierra Rural Electric Cooperative        3100
# 3    CA1006                           Frito-Lay, Inc.      101235
# ..      ...                                       ...         ...
# 274  CA3371                        BB ENERGY USA, LLC      104867
# 275  CA3376                        3 PR Trading, Inc.      104903
# 276  CA3382      Northrop Grumman Systems Corporation      104227
# 277  CA3386                  Corteva Agriscience, LLC      101733
# 278  CA3415                          City of San Jose      104793
#
#     reporting_period
# 0          2013-2014
# 1          2013-2014
# 1          2013-2014
# 2          2013-2014
# 3          2013-2014
# ..               ...
# 274             2021
# 275             2021
# 276             2021
# 277             2021
# 278             2021
#
# [1699 rows x 4 columns]

# %%
user_facility_df.loc[user_facility_df["user_id"] == "CA1279"]
# Out:
#     user_id            user_name facility_id reporting_period
# 119  CA1279  Phillips 66 Company      100303        2013-2014
# 119  CA1279  Phillips 66 Company      100329        2013-2014
# 119  CA1279  Phillips 66 Company      100351        2013-2014
# 119  CA1279  Phillips 66 Company      100913        2013-2014
# 119  CA1279  Phillips 66 Company      101226        2013-2014
# 115  CA1279  Phillips 66 Company      100303        2015-2017
# 115  CA1279  Phillips 66 Company      100329        2015-2017
# 115  CA1279  Phillips 66 Company      100351        2015-2017
# 115  CA1279  Phillips 66 Company      100913        2015-2017
# 115  CA1279  Phillips 66 Company      101226        2015-2017
# 115  CA1279  Phillips 66 Company      104010        2015-2017
# 98   CA1279  Phillips 66 Company      100303        2018-2020
# 98   CA1279  Phillips 66 Company      100329        2018-2020
# 98   CA1279  Phillips 66 Company      100351        2018-2020
# 98   CA1279  Phillips 66 Company      100913        2018-2020
# 98   CA1279  Phillips 66 Company      101226        2018-2020
# 98   CA1279  Phillips 66 Company      104010        2018-2020
# 92   CA1279  Phillips 66 Company      100303             2021
# 92   CA1279  Phillips 66 Company      100329             2021
# 92   CA1279  Phillips 66 Company      100351             2021
# 92   CA1279  Phillips 66 Company      100913             2021
# 92   CA1279  Phillips 66 Company      101226             2021
# 92   CA1279  Phillips 66 Company      104010             2021
